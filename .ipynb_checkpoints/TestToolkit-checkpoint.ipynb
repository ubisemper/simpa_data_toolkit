# %%
import sys
sys.path.append('/home/wytse/Desktop/led_system_modelling')
import NoiseModule as nm
import SimpaHelper as sh
from src.utils.cyberdyne_led_array_system import CyberdyneLEDArraySystem
from simpa import Tags
import matplotlib.pyplot as plt
import simpa as sp

# %%
hdf5_file_path = 'test_structure/61_gt/optical_attenuation_size_frequencyresponse_on_baseline.hdf5'
simpa_helper = sh.SimpaHelper(hdf5_file_path=hdf5_file_path)
sino = simpa_helper.extract_sinogram()
simpa_helper.reconstruct()
simpa_helper.visualize_reconstruction()
# Out:
# 2023-12-12 16:03:03,667 - DEBUG - Using $HOME$ path to search for config file: /home/wytse/path_config.env
# 2023-12-12 16:03:03,669 - DEBUG - Did not find path config in $HOME$: /home/wytse/path_config.env
# 2023-12-12 16:03:03,669 - DEBUG - Searching for path config in current working directory...
# 2023-12-12 16:03:03,670 - DEBUG - Found path_config.env in current working directory: /home/wytse/Desktop/pai_processing_toolkit/path_config.env
# 2023-12-12 16:03:03,696 - DEBUG - Retrieved MATLAB_BINARY_PATH=/usr/local/MATLAB/R2023b/bin/matlab
# 2023-12-12 16:03:03,696 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('sos', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'sos' has been given the value 1480
# ...

# %%
plt.imshow(sino)

# %%
noise_sino = nm.ring_artifacts(sino, 500, 50)
plt.imshow(noise_sino)

# %%
simpa_helper.save_sinogram(noise_sino, 'ghost_test')

# %%
simpa_ghost = sh.SimpaHelper(hdf5_file_path='ghost_test')
# Out:
# 2023-12-12 16:03:29,412 - DEBUG - Using $HOME$ path to search for config file: /home/wytse/path_config.env
# 2023-12-12 16:03:29,416 - DEBUG - Did not find path config in $HOME$: /home/wytse/path_config.env
# 2023-12-12 16:03:29,418 - DEBUG - Searching for path config in current working directory...
# 2023-12-12 16:03:29,420 - DEBUG - Found path_config.env in current working directory: /home/wytse/Desktop/pai_processing_toolkit/path_config.env

# %%
simpa_ghost.show_sinogram()

# %%
simpa_ghost.reconstruct()
# Out:
# 2023-12-12 16:03:45,298 - DEBUG - Retrieved MATLAB_BINARY_PATH=/usr/local/MATLAB/R2023b/bin/matlab
# 2023-12-12 16:03:45,298 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('sos', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'sos' has been given the value 1480
# 2023-12-12 16:03:45,299 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('alpha_coeff', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'alpha_coeff' has been given the value 0.01
# 2023-12-12 16:03:45,299 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('density', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'density' has been given the value 1000
# 2023-12-12 16:03:45,304 - INFO - Performing reconstruction...
# ...

# %%
simpa_ghost.visualize_reconstruction()

# %%
path_manager = sp.PathManager()

def reconstruct(hdf5_file_path, show_absorption=False):
    settings = sp.load_data_field(hdf5_file_path, Tags.SETTINGS)
    settings[Tags.WAVELENGTH] = settings[Tags.WAVELENGTHS][0]
    settings[Tags.IGNORE_QA_ASSERTIONS] = True
    
    settings.set_reconstruction_settings({
        Tags.ACOUSTIC_MODEL_BINARY_PATH: path_manager.get_matlab_binary_path(),
        Tags.ACOUSTIC_SIMULATION_3D: True,
        Tags.KWAVE_PROPERTY_ALPHA_POWER: 0.00,
        Tags.KWAVE_PROPERTY_SENSOR_RECORD: "p",
        Tags.KWAVE_PROPERTY_PMLInside: False,
        Tags.KWAVE_PROPERTY_PMLSize: [31, 32],
        Tags.KWAVE_PROPERTY_PMLAlpha: 1.5,
        Tags.KWAVE_PROPERTY_PlotPML: False,
        Tags.RECORDMOVIE: False,
        Tags.MOVIENAME: "visualization_log",
        Tags.ACOUSTIC_LOG_SCALE: True,
        Tags.DATA_FIELD_SPEED_OF_SOUND: 1480,
        Tags.DATA_FIELD_ALPHA_COEFF: 0.01,
        Tags.DATA_FIELD_DENSITY: 1000,
        Tags.SPACING_MM: settings[Tags.SPACING_MM],
        Tags.SENSOR_SAMPLING_RATE_MHZ: 40,
        # Tags.RECONSTRUCTION_BMODE_METHOD: Tags.RECONSTRUCTION_BMODE_METHOD_HILBERT_TRANSFORM,
        # Tags.RECONSTRUCTION_BMODE_AFTER_RECONSTRUCTION: True,
    })
    
    dim_x_mm = settings[Tags.DIM_VOLUME_X_MM]
    dim_y_mm = settings[Tags.DIM_VOLUME_Y_MM]
    dim_z_mm = settings[Tags.DIM_VOLUME_Z_MM]
    spacing = settings[Tags.SPACING_MM]
    
    device = CyberdyneLEDArraySystem(device_position_mm=np.array([dim_x_mm/2, dim_y_mm/2, 0]),
                                         field_of_view_extent_mm=np.asarray([-10, 10, -2, 2, 2, 20]))
    
    sp.DelayAndSumAdapter(settings).run(device)

    sp.visualise_data(path_to_hdf5_file=hdf5_file_path,
                      wavelength=settings[Tags.WAVELENGTH],
              
                      show_reconstructed_data=True,
                      show_xz_only=True, show_absorption=show_absorption)
    path_to_hdf5_file=hdf5_file_path
    wavelength=settings[Tags.WAVELENGTH]
    file = load_hdf5(path_to_hdf5_file)
    reconstructed_data = get_simpa_output(file, Tags.DATA_FIELD_RECONSTRUCTED_DATA, wavelength)
    print(reconstructed_data.shape)
# Out:
# 2023-12-12 16:04:53,052 - DEBUG - Using $HOME$ path to search for config file: /home/wytse/path_config.env
# 2023-12-12 16:04:53,053 - DEBUG - Did not find path config in $HOME$: /home/wytse/path_config.env
# 2023-12-12 16:04:53,053 - DEBUG - Searching for path config in current working directory...
# 2023-12-12 16:04:53,054 - DEBUG - Found path_config.env in current working directory: /home/wytse/Desktop/pai_processing_toolkit/path_config.env

# %%
reconstruct('ghost_test')
# Out:
# 2023-12-12 16:05:35,936 - DEBUG - Retrieved MATLAB_BINARY_PATH=/usr/local/MATLAB/R2023b/bin/matlab
# 2023-12-12 16:05:35,937 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('sos', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'sos' has been given the value 1480
# 2023-12-12 16:05:35,937 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('alpha_coeff', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'alpha_coeff' has been given the value 0.01
# 2023-12-12 16:05:35,938 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('density', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'density' has been given the value 1000
# ...
