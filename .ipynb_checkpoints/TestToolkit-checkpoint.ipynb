# %%
import sys
sys.path.append('/home/wytse/Desktop/led_system_modelling')
import NoiseModule as nm
import SimpaHelper as sh

# %%
hdf5_file_path = 'test_structure/61_gt/optical_attenuation_size_frequencyresponse_on_baseline.hdf5'
simpa_helper = sh.SimpaHelper(hdf5_file_path=hdf5_file_path)

# %%
simpa_helper.reconstruct()
# Out:
# 2023-12-12 13:24:04,254 - DEBUG - Retrieved MATLAB_BINARY_PATH=/usr/local/MATLAB/R2023b/bin/matlab
# 2023-12-12 13:24:04,254 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('sos', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'sos' has been given the value 1480
# 2023-12-12 13:24:04,254 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('alpha_coeff', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'alpha_coeff' has been given the value 0.01
# 2023-12-12 13:24:04,255 - WARNING - The key for the Settings dictionary should be a tuple in the form of ('density', (data_type_1, data_type_2, ...)). The tuple of data types specifies all possible types, the value can have.
# The key 'density' has been given the value 1000
# 2023-12-12 13:24:04,259 - INFO - Performing reconstruction...
# 2023-12-12 13:24:04,265 - DEBUG - Using a time_spacing of 2.5e-05
# 2023-12-12 13:24:04,265 - DEBUG - Reconstructing with spacing from component_settings: 0.09765625
# 2023-12-12 13:24:04,289 - DEBUG - Processing is done on cuda
# 2023-12-12 13:24:04,408 - DEBUG - Field of view: [-20  20   0   0   0  40]
# 2023-12-12 13:24:04,409 - DEBUG - FOV X: -19.970703125 - 19.970703125
# 2023-12-12 13:24:04,409 - DEBUG - FOV Y: 0.0 - 39.970703125
# 2023-12-12 13:24:04,409 - DEBUG - FOV Z: 0.0 - 0.0
# 2023-12-12 13:24:04,414 - DEBUG - Number of pixels in X dimension: 409, Y dimension: 409, Z dimension: 1 ,number of sensor elements: 128
# 2023-12-12 13:24:04,546 - INFO - Performing reconstruction...[Done]
# /home/wytse/Desktop/packages/venv/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
simpa_helper.visualize_reconstruction()

# %%
simpa_helper.show_sinogram()

# %%
simpa_helper.extract_sinogram(save_to_file=True)
# Out:
# Extracted Number: 61
# array([[ 2.72731271e+00,  2.23006432e+00,  1.97692412e+00, ...,
#         -2.35341463e-01, -2.67194878e-01, -2.81055400e-01],
#        [ 7.83002728e+00,  7.27248585e+00,  6.94253430e+00, ...,
#         -2.93393412e+00, -3.59137594e+00, -3.37890427e+00],
#        [ 1.07667533e+01,  1.06136998e+01,  1.04704986e+01, ...,
#         -1.41507046e+01, -1.57125025e+01, -1.50469525e+01],
#        ...,
#        [ 1.01158282e+01,  9.86143326e+00,  9.57994204e+00, ...,
#         -1.07494452e+01, -1.21697545e+01, -1.27971576e+01],
#        [ 7.20761820e+00,  6.44691082e+00,  5.93784110e+00, ...,
#         -1.25962193e+00, -1.81770573e+00, -1.55585288e+00],
#        [ 1.30308158e+00,  1.05658449e+00,  9.58165684e-01, ...,
#         -2.34442204e-01, -1.18400397e-01, -1.55499300e-02]])

# %%
simpa_helper.reconstruct(custom_sinogram_path='test_structure/61_gt/61_sinogram.npz')
# Out:
# /home/wytse/Desktop/packages/venv/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
simpa_helper.visualize_reconstruction()

# %%
import numpy as np
data = np.load('test_structure/61_gt/temp_name.npz')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 data = np.load('test_structure/61_gt/temp_name.npz')
#
# File ~/Desktop/packages/venv/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_structure/61_gt/temp_name.npz'

# %%
data['sinogram']
# Out:
# array([[ 2.72731271e+00,  2.23006432e+00,  1.97692412e+00, ...,
#         -2.35341463e-01, -2.67194878e-01, -2.81055400e-01],
#        [ 7.83002728e+00,  7.27248585e+00,  6.94253430e+00, ...,
#         -2.93393412e+00, -3.59137594e+00, -3.37890427e+00],
#        [ 1.07667533e+01,  1.06136998e+01,  1.04704986e+01, ...,
#         -1.41507046e+01, -1.57125025e+01, -1.50469525e+01],
#        ...,
#        [ 1.01158282e+01,  9.86143326e+00,  9.57994204e+00, ...,
#         -1.07494452e+01, -1.21697545e+01, -1.27971576e+01],
#        [ 7.20761820e+00,  6.44691082e+00,  5.93784110e+00, ...,
#         -1.25962193e+00, -1.81770573e+00, -1.55585288e+00],
#        [ 1.30308158e+00,  1.05658449e+00,  9.58165684e-01, ...,
#         -2.34442204e-01, -1.18400397e-01, -1.55499300e-02]])

# %%
sino = simpa_helper.extract_sinogram()

# %%
noisey_sino = nm.ghost_artifacts(sino, 0, 200)

# %%
import matplotlib.pyplot as plt

# %%
simpa_helper.reconstruct(sinogram_data=noisey_sino)
# Out:
# ## Using input for reconstruction

# %%
simpa_helper.visualize_reconstruction()

# %%
simpa_helper.reconstruct()
# Out:
# Using original sinogram for reconstruction

# %%
simpa_helper.visualize_reconstruction()
